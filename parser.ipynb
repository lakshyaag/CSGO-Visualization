# %%
import pandas as pd
import os
from csgo.parser import DemoParser

# %%
def demo_parse(demofile):
    
    parser = DemoParser(demofile = f"../demos/{demofile}",
                        parse_rate=128)

    match_data = parser.parse(return_type='df')

    return({"rounds": match_data['rounds'], 
            "kills": match_data['kills'],
           "grenades": match_data['grenades'],
           "damages": match_data['damages'],
           "flashes": match_data['flashes'],
            "bomb_events": match_data['bombEvents'],
           "playerFrames": match_data['playerFrames']})

# %%
def get_demo_files(folder):
    files = [f"{folder}/{file}" for file in os.listdir(f"../demos/{folder}/")]
    return(files)

# %%
def append_rounds_kills(match_data):
    match_rounds = pd.DataFrame()
    match_kills = pd.DataFrame()
    match_grenades = pd.DataFrame()
    match_damages = pd.DataFrame()
    match_flashes = pd.DataFrame()
    match_bomb_events = pd.DataFrame()
    match_frames = pd.DataFrame()
    
    for map_ in match_data:
        match_rounds = match_rounds.append(map_['rounds'])
        match_kills = match_kills.append(map_['kills'])
        match_grenades = match_grenades.append(map_['grenades'])
        match_damages = match_damages.append(map_['damages'])
        match_flashes = match_flashes.append(map_['flashes'])
        match_bomb_events = match_bomb_events.append(map_['bomb_events'])
        match_frames = match_frames.append(map_['playerFrames'])
        
    return({
        'rounds': match_rounds,
        'kills': match_kills,
        'grenades': match_grenades,
        'damages': match_damages,
        'flashes': match_flashes,
        'bomb_events': match_bomb_events,
        'playerFrames': match_frames})

# %%
def save_data(match_df, id_):
    
    os.mkdir(f"./data_files/{id_}")
    
    match_df['rounds'].to_csv(f"./data_files/{id_}/{id_}_rounds.csv", index=False)
    match_df['kills'].to_csv(f"./data_files/{id_}/{id_}_kills.csv", index=False)
    match_df['grenades'].to_csv(f"./data_files/{id_}/{id_}_grenades.csv", index=False)
    match_df['damages'].to_csv(f"./data_files/{id_}/{id_}_damages.csv", index=False)
    match_df['flashes'].to_csv(f"./data_files/{id_}/{id_}_flashes.csv", index=False)
    match_df['bomb_events'].to_csv(f"./data_files/{id_}/{id_}_bomb_events.csv", index=False)
    match_df['playerFrames'].to_csv(f"./data_files/{id_}/{id_}_playerFrames.csv", index=False)

# %%
def parse_match(folder, id_):
    
    demo_files = get_demo_files(folder)
    demo_dfs = [demo_parse(file) for file in demo_files]
    
    match_df = append_rounds_kills(demo_dfs)
    
    save_data(match_df, id_)
    
    print(f"Parsed demos for {id_}.")
    
    return(match_df)

# %%
tournament = next(os.walk("../demos/PGL Stockholm Major 2021 - Challengers"))[1]
tournament_ids = [x.replace("PGL-Major-Stockholm-2021-Challengers-Stage-", "") for x in tournament]

# %%
for i in range(0, len(tournament)):
    parse_match(f"PGL Stockholm Major 2021 - Challengers/{tournament[i]}", id_=tournament_ids[i])
# Out:
# 17:18:36 [INFO] Go version>=1.14.0
# 17:18:36 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-godsent-bo3\astralis-vs-godsent-m1-nuke.dem
# 17:18:36 [INFO] Setting demo id to astralis-vs-godsent-m1-nuke
# 17:18:36 [INFO] Setting parse rate to 128
# 17:18:36 [INFO] Setting trade time to 5
# 17:18:36 [INFO] Setting buy style to hltv
# 17:18:36 [INFO] Rollup damages set to False
# 17:18:36 [INFO] Parse frames set to True
# 17:18:36 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:18:36 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-godsent-bo3\astralis-vs-godsent-m1-nuke.dem
# 17:18:58 [INFO] Wrote demo parse output to astralis-vs-godsent-m1-nuke.json
# 17:18:58 [INFO] Reading in JSON from astralis-vs-godsent-m1-nuke.json
# 17:18:59 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:18:59 [INFO] Successfully parsed JSON output
# 17:18:59 [INFO] Successfully returned JSON output
# 17:18:59 [INFO] Returned dataframe output
# 17:19:00 [INFO] Go version>=1.14.0
# 17:19:00 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-godsent-bo3\astralis-vs-godsent-m2-vertigo.dem
# 17:19:00 [INFO] Setting demo id to astralis-vs-godsent-m2-vertigo
# 17:19:00 [INFO] Setting parse rate to 128
# 17:19:00 [INFO] Setting trade time to 5
# 17:19:00 [INFO] Setting buy style to hltv
# 17:19:00 [INFO] Rollup damages set to False
# 17:19:00 [INFO] Parse frames set to True
# 17:19:00 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:19:00 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-godsent-bo3\astralis-vs-godsent-m2-vertigo.dem
# 17:19:12 [INFO] Wrote demo parse output to astralis-vs-godsent-m2-vertigo.json
# 17:19:12 [INFO] Reading in JSON from astralis-vs-godsent-m2-vertigo.json
# 17:19:13 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:19:13 [INFO] Successfully parsed JSON output
# 17:19:13 [INFO] Successfully returned JSON output
# 17:19:13 [INFO] Returned dataframe output
# Parsed demos for astralis-vs-godsent-bo3.
# 17:19:15 [INFO] Go version>=1.14.0
# 17:19:15 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-pain-bo3\astralis-vs-pain-m1-nuke.dem
# 17:19:15 [INFO] Setting demo id to astralis-vs-pain-m1-nuke
# 17:19:15 [INFO] Setting parse rate to 128
# 17:19:15 [INFO] Setting trade time to 5
# 17:19:15 [INFO] Setting buy style to hltv
# 17:19:15 [INFO] Rollup damages set to False
# 17:19:15 [INFO] Parse frames set to True
# 17:19:15 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:19:15 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-pain-bo3\astralis-vs-pain-m1-nuke.dem
# 17:19:26 [INFO] Wrote demo parse output to astralis-vs-pain-m1-nuke.json
# 17:19:26 [INFO] Reading in JSON from astralis-vs-pain-m1-nuke.json
# 17:19:27 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:19:27 [INFO] Successfully parsed JSON output
# 17:19:27 [INFO] Successfully returned JSON output
# 17:19:28 [INFO] Returned dataframe output
# 17:19:28 [INFO] Go version>=1.14.0
# 17:19:28 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-pain-bo3\astralis-vs-pain-m2-ancient.dem
# 17:19:28 [INFO] Setting demo id to astralis-vs-pain-m2-ancient
# 17:19:28 [INFO] Setting parse rate to 128
# 17:19:28 [INFO] Setting trade time to 5
# 17:19:28 [INFO] Setting buy style to hltv
# 17:19:28 [INFO] Rollup damages set to False
# 17:19:28 [INFO] Parse frames set to True
# 17:19:28 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:19:28 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-astralis-vs-pain-bo3\astralis-vs-pain-m2-ancient.dem
# 17:19:45 [INFO] Wrote demo parse output to astralis-vs-pain-m2-ancient.json
# 17:19:45 [INFO] Reading in JSON from astralis-vs-pain-m2-ancient.json
# 17:19:46 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:19:46 [INFO] Successfully parsed JSON output
# 17:19:46 [INFO] Successfully returned JSON output
# 17:19:47 [INFO] Returned dataframe output
# Parsed demos for astralis-vs-pain-bo3.
# 17:19:49 [INFO] Go version>=1.14.0
# 17:19:49 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m1-dust2.dem
# 17:19:49 [INFO] Setting demo id to big-vs-ence-m1-dust2
# 17:19:49 [INFO] Setting parse rate to 128
# 17:19:49 [INFO] Setting trade time to 5
# 17:19:49 [INFO] Setting buy style to hltv
# 17:19:49 [INFO] Rollup damages set to False
# 17:19:49 [INFO] Parse frames set to True
# 17:19:49 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:19:49 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m1-dust2.dem
# 17:20:01 [INFO] Wrote demo parse output to big-vs-ence-m1-dust2.json
# 17:20:01 [INFO] Reading in JSON from big-vs-ence-m1-dust2.json
# 17:20:02 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:20:02 [INFO] Successfully parsed JSON output
# 17:20:02 [INFO] Successfully returned JSON output
# 17:20:02 [INFO] Returned dataframe output
# 17:20:03 [INFO] Go version>=1.14.0
# 17:20:03 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m2-mirage.dem
# 17:20:03 [INFO] Setting demo id to big-vs-ence-m2-mirage
# 17:20:03 [INFO] Setting parse rate to 128
# 17:20:03 [INFO] Setting trade time to 5
# 17:20:03 [INFO] Setting buy style to hltv
# 17:20:03 [INFO] Rollup damages set to False
# 17:20:03 [INFO] Parse frames set to True
# 17:20:03 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:20:03 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m2-mirage.dem
# 17:20:14 [INFO] Wrote demo parse output to big-vs-ence-m2-mirage.json
# 17:20:14 [INFO] Reading in JSON from big-vs-ence-m2-mirage.json
# 17:20:14 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:20:14 [INFO] Successfully parsed JSON output
# 17:20:14 [INFO] Successfully returned JSON output
# 17:20:15 [INFO] Returned dataframe output
# 17:20:15 [INFO] Go version>=1.14.0
# 17:20:15 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m3-nuke.dem
# 17:20:15 [INFO] Setting demo id to big-vs-ence-m3-nuke
# 17:20:15 [INFO] Setting parse rate to 128
# 17:20:15 [INFO] Setting trade time to 5
# 17:20:15 [INFO] Setting buy style to hltv
# 17:20:15 [INFO] Rollup damages set to False
# 17:20:15 [INFO] Parse frames set to True
# 17:20:15 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:20:15 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-ence-bo3\big-vs-ence-m3-nuke.dem
# 17:20:27 [INFO] Wrote demo parse output to big-vs-ence-m3-nuke.json
# 17:20:27 [INFO] Reading in JSON from big-vs-ence-m3-nuke.json
# 17:20:28 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:20:28 [INFO] Successfully parsed JSON output
# 17:20:28 [INFO] Successfully returned JSON output
# 17:20:28 [INFO] Returned dataframe output
# Parsed demos for big-vs-ence-bo3.
# 17:20:30 [INFO] Go version>=1.14.0
# 17:20:30 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m1-dust2.dem
# 17:20:30 [INFO] Setting demo id to big-vs-mouz-m1-dust2
# 17:20:30 [INFO] Setting parse rate to 128
# 17:20:30 [INFO] Setting trade time to 5
# 17:20:30 [INFO] Setting buy style to hltv
# 17:20:30 [INFO] Rollup damages set to False
# 17:20:30 [INFO] Parse frames set to True
# 17:20:30 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:20:30 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m1-dust2.dem
# 17:20:43 [INFO] Wrote demo parse output to big-vs-mouz-m1-dust2.json
# 17:20:43 [INFO] Reading in JSON from big-vs-mouz-m1-dust2.json
# 17:20:44 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:20:44 [INFO] Successfully parsed JSON output
# 17:20:44 [INFO] Successfully returned JSON output
# 17:20:44 [INFO] Returned dataframe output
# 17:20:45 [INFO] Go version>=1.14.0
# 17:20:45 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m2-inferno.dem
# 17:20:45 [INFO] Setting demo id to big-vs-mouz-m2-inferno
# 17:20:45 [INFO] Setting parse rate to 128
# 17:20:45 [INFO] Setting trade time to 5
# 17:20:45 [INFO] Setting buy style to hltv
# 17:20:45 [INFO] Rollup damages set to False
# 17:20:45 [INFO] Parse frames set to True
# 17:20:45 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:20:45 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m2-inferno.dem
# 17:20:58 [INFO] Wrote demo parse output to big-vs-mouz-m2-inferno.json
# 17:20:58 [INFO] Reading in JSON from big-vs-mouz-m2-inferno.json
# 17:20:59 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:20:59 [INFO] Successfully parsed JSON output
# 17:20:59 [INFO] Successfully returned JSON output
# 17:20:59 [INFO] Returned dataframe output
# 17:21:00 [INFO] Go version>=1.14.0
# 17:21:00 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m3-nuke.dem
# 17:21:00 [INFO] Setting demo id to big-vs-mouz-m3-nuke
# 17:21:00 [INFO] Setting parse rate to 128
# 17:21:00 [INFO] Setting trade time to 5
# 17:21:00 [INFO] Setting buy style to hltv
# 17:21:00 [INFO] Rollup damages set to False
# 17:21:00 [INFO] Parse frames set to True
# 17:21:00 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:21:00 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-big-vs-mouz-bo3\big-vs-mouz-m3-nuke.dem
# 17:21:13 [INFO] Wrote demo parse output to big-vs-mouz-m3-nuke.json
# 17:21:13 [INFO] Reading in JSON from big-vs-mouz-m3-nuke.json
# 17:21:14 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:21:14 [INFO] Successfully parsed JSON output
# 17:21:14 [INFO] Successfully returned JSON output
# 17:21:14 [INFO] Returned dataframe output
# Parsed demos for big-vs-mouz-bo3.
# 17:21:16 [INFO] Go version>=1.14.0
# 17:21:16 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-ence-vs-mouz-nuke\ence-vs-mouz-nuke.dem
# 17:21:16 [INFO] Setting demo id to ence-vs-mouz-nuke
# 17:21:16 [INFO] Setting parse rate to 128
# 17:21:16 [INFO] Setting trade time to 5
# 17:21:16 [INFO] Setting buy style to hltv
# 17:21:16 [INFO] Rollup damages set to False
# 17:21:16 [INFO] Parse frames set to True
# 17:21:16 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:21:16 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-ence-vs-mouz-nuke\ence-vs-mouz-nuke.dem
# 17:21:28 [INFO] Wrote demo parse output to ence-vs-mouz-nuke.json
# 17:21:28 [INFO] Reading in JSON from ence-vs-mouz-nuke.json
# 17:21:29 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:21:29 [INFO] Successfully parsed JSON output
# 17:21:29 [INFO] Successfully returned JSON output
# 17:21:30 [INFO] Returned dataframe output
# Parsed demos for ence-vs-mouz-nuke.
# 17:21:30 [INFO] Go version>=1.14.0
# 17:21:30 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-faze-vs-virtus-pro-bo3\faze-vs-virtus-pro-m1-mirage.dem
# 17:21:30 [INFO] Setting demo id to faze-vs-virtus-pro-m1-mirage
# 17:21:30 [INFO] Setting parse rate to 128
# 17:21:30 [INFO] Setting trade time to 5
# 17:21:30 [INFO] Setting buy style to hltv
# 17:21:30 [INFO] Rollup damages set to False
# 17:21:30 [INFO] Parse frames set to True
# 17:21:30 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:21:30 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-faze-vs-virtus-pro-bo3\faze-vs-virtus-pro-m1-mirage.dem
# 17:21:45 [INFO] Wrote demo parse output to faze-vs-virtus-pro-m1-mirage.json
# 17:21:45 [INFO] Reading in JSON from faze-vs-virtus-pro-m1-mirage.json
# 17:21:46 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:21:46 [INFO] Successfully parsed JSON output
# 17:21:46 [INFO] Successfully returned JSON output
# 17:21:46 [INFO] Returned dataframe output
# 17:21:47 [INFO] Go version>=1.14.0
# 17:21:47 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-faze-vs-virtus-pro-bo3\faze-vs-virtus-pro-m2-ancient.dem
# 17:21:47 [INFO] Setting demo id to faze-vs-virtus-pro-m2-ancient
# 17:21:47 [INFO] Setting parse rate to 128
# 17:21:47 [INFO] Setting trade time to 5
# 17:21:47 [INFO] Setting buy style to hltv
# 17:21:47 [INFO] Rollup damages set to False
# 17:21:47 [INFO] Parse frames set to True
# 17:21:47 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:21:47 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-faze-vs-virtus-pro-bo3\faze-vs-virtus-pro-m2-ancient.dem
# 17:21:57 [INFO] Wrote demo parse output to faze-vs-virtus-pro-m2-ancient.json
# 17:21:57 [INFO] Reading in JSON from faze-vs-virtus-pro-m2-ancient.json
# 17:21:58 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:21:58 [INFO] Successfully parsed JSON output
# 17:21:58 [INFO] Successfully returned JSON output
# 17:21:58 [INFO] Returned dataframe output
# Parsed demos for faze-vs-virtus-pro-bo3.
# 17:22:00 [INFO] Go version>=1.14.0
# 17:22:00 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m1-vertigo.dem
# 17:22:00 [INFO] Setting demo id to heroic-vs-copenhagen-flames-m1-vertigo
# 17:22:00 [INFO] Setting parse rate to 128
# 17:22:00 [INFO] Setting trade time to 5
# 17:22:00 [INFO] Setting buy style to hltv
# 17:22:00 [INFO] Rollup damages set to False
# 17:22:00 [INFO] Parse frames set to True
# 17:22:00 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:22:00 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m1-vertigo.dem
# 17:22:11 [INFO] Wrote demo parse output to heroic-vs-copenhagen-flames-m1-vertigo.json
# 17:22:11 [INFO] Reading in JSON from heroic-vs-copenhagen-flames-m1-vertigo.json
# 17:22:11 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:22:11 [INFO] Successfully parsed JSON output
# 17:22:11 [INFO] Successfully returned JSON output
# 17:22:12 [INFO] Returned dataframe output
# 17:22:12 [INFO] Go version>=1.14.0
# 17:22:12 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m2-nuke.dem
# 17:22:12 [INFO] Setting demo id to heroic-vs-copenhagen-flames-m2-nuke
# 17:22:12 [INFO] Setting parse rate to 128
# 17:22:12 [INFO] Setting trade time to 5
# 17:22:12 [INFO] Setting buy style to hltv
# 17:22:12 [INFO] Rollup damages set to False
# 17:22:12 [INFO] Parse frames set to True
# 17:22:12 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:22:12 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m2-nuke.dem
# 17:22:24 [INFO] Wrote demo parse output to heroic-vs-copenhagen-flames-m2-nuke.json
# 17:22:24 [INFO] Reading in JSON from heroic-vs-copenhagen-flames-m2-nuke.json
# 17:22:25 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:22:25 [INFO] Successfully parsed JSON output
# 17:22:25 [INFO] Successfully returned JSON output
# 17:22:26 [INFO] Returned dataframe output
# 17:22:26 [INFO] Go version>=1.14.0
# 17:22:26 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m3-overpass.dem
# 17:22:26 [INFO] Setting demo id to heroic-vs-copenhagen-flames-m3-overpass
# 17:22:26 [INFO] Setting parse rate to 128
# 17:22:26 [INFO] Setting trade time to 5
# 17:22:26 [INFO] Setting buy style to hltv
# 17:22:26 [INFO] Rollup damages set to False
# 17:22:26 [INFO] Parse frames set to True
# 17:22:26 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:22:26 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-copenhagen-flames-bo3\heroic-vs-copenhagen-flames-m3-overpass.dem
# 17:22:42 [INFO] Wrote demo parse output to heroic-vs-copenhagen-flames-m3-overpass.json
# 17:22:42 [INFO] Reading in JSON from heroic-vs-copenhagen-flames-m3-overpass.json
# 17:22:42 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:22:42 [INFO] Successfully parsed JSON output
# 17:22:42 [INFO] Successfully returned JSON output
# 17:22:43 [INFO] Returned dataframe output
# Parsed demos for heroic-vs-copenhagen-flames-bo3.
# 17:22:45 [INFO] Go version>=1.14.0
# 17:22:45 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m1-ancient.dem
# 17:22:45 [INFO] Setting demo id to heroic-vs-entropiq-m1-ancient
# 17:22:45 [INFO] Setting parse rate to 128
# 17:22:45 [INFO] Setting trade time to 5
# 17:22:45 [INFO] Setting buy style to hltv
# 17:22:45 [INFO] Rollup damages set to False
# 17:22:45 [INFO] Parse frames set to True
# 17:22:45 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:22:45 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m1-ancient.dem
# 17:22:56 [INFO] Wrote demo parse output to heroic-vs-entropiq-m1-ancient.json
# 17:22:56 [INFO] Reading in JSON from heroic-vs-entropiq-m1-ancient.json
# 17:22:57 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:22:57 [INFO] Successfully parsed JSON output
# 17:22:57 [INFO] Successfully returned JSON output
# 17:22:58 [INFO] Returned dataframe output
# 17:22:58 [INFO] Go version>=1.14.0
# 17:22:58 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m2-nuke.dem
# 17:22:58 [INFO] Setting demo id to heroic-vs-entropiq-m2-nuke
# 17:22:58 [INFO] Setting parse rate to 128
# 17:22:58 [INFO] Setting trade time to 5
# 17:22:58 [INFO] Setting buy style to hltv
# 17:22:58 [INFO] Rollup damages set to False
# 17:22:58 [INFO] Parse frames set to True
# 17:22:58 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:22:58 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m2-nuke.dem
# 17:23:10 [INFO] Wrote demo parse output to heroic-vs-entropiq-m2-nuke.json
# 17:23:10 [INFO] Reading in JSON from heroic-vs-entropiq-m2-nuke.json
# 17:23:11 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:23:11 [INFO] Successfully parsed JSON output
# 17:23:11 [INFO] Successfully returned JSON output
# 17:23:11 [INFO] Returned dataframe output
# 17:23:12 [INFO] Go version>=1.14.0
# 17:23:12 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m3-mirage.dem
# 17:23:12 [INFO] Setting demo id to heroic-vs-entropiq-m3-mirage
# 17:23:12 [INFO] Setting parse rate to 128
# 17:23:12 [INFO] Setting trade time to 5
# 17:23:12 [INFO] Setting buy style to hltv
# 17:23:12 [INFO] Rollup damages set to False
# 17:23:12 [INFO] Parse frames set to True
# 17:23:12 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:23:12 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-entropiq-bo3\heroic-vs-entropiq-m3-mirage.dem
# 17:23:21 [INFO] Wrote demo parse output to heroic-vs-entropiq-m3-mirage.json
# 17:23:21 [INFO] Reading in JSON from heroic-vs-entropiq-m3-mirage.json
# 17:23:22 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:23:22 [INFO] Successfully parsed JSON output
# 17:23:22 [INFO] Successfully returned JSON output
# 17:23:22 [INFO] Returned dataframe output
# Parsed demos for heroic-vs-entropiq-bo3.
# 17:23:25 [INFO] Go version>=1.14.0
# 17:23:25 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-movistar-riders-bo3\heroic-vs-movistar-riders-m1-inferno.dem
# 17:23:25 [INFO] Setting demo id to heroic-vs-movistar-riders-m1-inferno
# 17:23:25 [INFO] Setting parse rate to 128
# 17:23:25 [INFO] Setting trade time to 5
# 17:23:25 [INFO] Setting buy style to hltv
# 17:23:25 [INFO] Rollup damages set to False
# 17:23:25 [INFO] Parse frames set to True
# 17:23:25 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:23:25 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-movistar-riders-bo3\heroic-vs-movistar-riders-m1-inferno.dem
# 17:23:36 [INFO] Wrote demo parse output to heroic-vs-movistar-riders-m1-inferno.json
# 17:23:36 [INFO] Reading in JSON from heroic-vs-movistar-riders-m1-inferno.json
# 17:23:37 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:23:37 [INFO] Successfully parsed JSON output
# 17:23:37 [INFO] Successfully returned JSON output
# 17:23:37 [INFO] Returned dataframe output
# 17:23:38 [INFO] Go version>=1.14.0
# 17:23:38 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-movistar-riders-bo3\heroic-vs-movistar-riders-m2-overpass.dem
# 17:23:38 [INFO] Setting demo id to heroic-vs-movistar-riders-m2-overpass
# 17:23:38 [INFO] Setting parse rate to 128
# 17:23:38 [INFO] Setting trade time to 5
# 17:23:38 [INFO] Setting buy style to hltv
# 17:23:38 [INFO] Rollup damages set to False
# 17:23:38 [INFO] Parse frames set to True
# 17:23:38 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:23:38 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-heroic-vs-movistar-riders-bo3\heroic-vs-movistar-riders-m2-overpass.dem
# 17:23:54 [INFO] Wrote demo parse output to heroic-vs-movistar-riders-m2-overpass.json
# 17:23:54 [INFO] Reading in JSON from heroic-vs-movistar-riders-m2-overpass.json
# 17:23:55 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:23:55 [INFO] Successfully parsed JSON output
# 17:23:55 [INFO] Successfully returned JSON output
# 17:23:56 [INFO] Returned dataframe output
# 17:23:57 [INFO] Go version>=1.14.0
# Parsed demos for heroic-vs-movistar-riders-bo3.
# 17:23:57 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m1-mirage.dem
# 17:23:57 [INFO] Setting demo id to mouz-vs-renegades-m1-mirage
# 17:23:57 [INFO] Setting parse rate to 128
# 17:23:57 [INFO] Setting trade time to 5
# 17:23:57 [INFO] Setting buy style to hltv
# 17:23:57 [INFO] Rollup damages set to False
# 17:23:57 [INFO] Parse frames set to True
# 17:23:57 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:23:57 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m1-mirage.dem
# 17:24:11 [INFO] Wrote demo parse output to mouz-vs-renegades-m1-mirage.json
# 17:24:11 [INFO] Reading in JSON from mouz-vs-renegades-m1-mirage.json
# 17:24:11 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:24:11 [INFO] Successfully parsed JSON output
# 17:24:11 [INFO] Successfully returned JSON output
# 17:24:12 [INFO] Returned dataframe output
# 17:24:12 [INFO] Go version>=1.14.0
# 17:24:12 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m2-inferno.dem
# 17:24:12 [INFO] Setting demo id to mouz-vs-renegades-m2-inferno
# 17:24:12 [INFO] Setting parse rate to 128
# 17:24:12 [INFO] Setting trade time to 5
# 17:24:12 [INFO] Setting buy style to hltv
# 17:24:12 [INFO] Rollup damages set to False
# 17:24:12 [INFO] Parse frames set to True
# 17:24:12 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:24:12 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m2-inferno.dem
# 17:24:25 [INFO] Wrote demo parse output to mouz-vs-renegades-m2-inferno.json
# 17:24:25 [INFO] Reading in JSON from mouz-vs-renegades-m2-inferno.json
# 17:24:26 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:24:26 [INFO] Successfully parsed JSON output
# 17:24:26 [INFO] Successfully returned JSON output
# 17:24:27 [INFO] Returned dataframe output
# 17:24:27 [INFO] Go version>=1.14.0
# 17:24:27 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m3-vertigo.dem
# 17:24:27 [INFO] Setting demo id to mouz-vs-renegades-m3-vertigo
# 17:24:27 [INFO] Setting parse rate to 128
# 17:24:27 [INFO] Setting trade time to 5
# 17:24:27 [INFO] Setting buy style to hltv
# 17:24:27 [INFO] Rollup damages set to False
# 17:24:27 [INFO] Parse frames set to True
# 17:24:27 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:24:27 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-mouz-vs-renegades-bo3\mouz-vs-renegades-m3-vertigo.dem
# 17:24:38 [INFO] Wrote demo parse output to mouz-vs-renegades-m3-vertigo.json
# 17:24:38 [INFO] Reading in JSON from mouz-vs-renegades-m3-vertigo.json
# 17:24:38 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:24:38 [INFO] Successfully parsed JSON output
# 17:24:38 [INFO] Successfully returned JSON output
# 17:24:39 [INFO] Returned dataframe output
# Parsed demos for mouz-vs-renegades-bo3.
# 17:24:41 [INFO] Go version>=1.14.0
# 17:24:41 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-entropiq-mirage\movistar-riders-vs-entropiq-mirage.dem
# 17:24:41 [INFO] Setting demo id to movistar-riders-vs-entropiq-mirage
# 17:24:41 [INFO] Setting parse rate to 128
# 17:24:41 [INFO] Setting trade time to 5
# 17:24:41 [INFO] Setting buy style to hltv
# 17:24:41 [INFO] Rollup damages set to False
# 17:24:41 [INFO] Parse frames set to True
# 17:24:41 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:24:41 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-entropiq-mirage\movistar-riders-vs-entropiq-mirage.dem
# 17:24:53 [INFO] Wrote demo parse output to movistar-riders-vs-entropiq-mirage.json
# 17:24:53 [INFO] Reading in JSON from movistar-riders-vs-entropiq-mirage.json
# 17:24:54 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:24:54 [INFO] Successfully parsed JSON output
# 17:24:54 [INFO] Successfully returned JSON output
# 17:24:55 [INFO] Returned dataframe output
# Parsed demos for movistar-riders-vs-entropiq-mirage.
# 17:24:56 [INFO] Go version>=1.14.0
# 17:24:56 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m1-inferno.dem
# 17:24:56 [INFO] Setting demo id to movistar-riders-vs-tyloo-m1-inferno
# 17:24:56 [INFO] Setting parse rate to 128
# 17:24:56 [INFO] Setting trade time to 5
# 17:24:56 [INFO] Setting buy style to hltv
# 17:24:56 [INFO] Rollup damages set to False
# 17:24:56 [INFO] Parse frames set to True
# 17:24:56 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:24:56 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m1-inferno.dem
# 17:25:12 [INFO] Wrote demo parse output to movistar-riders-vs-tyloo-m1-inferno.json
# 17:25:12 [INFO] Reading in JSON from movistar-riders-vs-tyloo-m1-inferno.json
# 17:25:13 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:25:13 [INFO] Successfully parsed JSON output
# 17:25:13 [INFO] Successfully returned JSON output
# 17:25:14 [INFO] Returned dataframe output
# 17:25:14 [INFO] Go version>=1.14.0
# 17:25:14 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m2-mirage.dem
# 17:25:14 [INFO] Setting demo id to movistar-riders-vs-tyloo-m2-mirage
# 17:25:14 [INFO] Setting parse rate to 128
# 17:25:14 [INFO] Setting trade time to 5
# 17:25:14 [INFO] Setting buy style to hltv
# 17:25:14 [INFO] Rollup damages set to False
# 17:25:14 [INFO] Parse frames set to True
# 17:25:14 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:25:14 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m2-mirage.dem
# 17:25:26 [INFO] Wrote demo parse output to movistar-riders-vs-tyloo-m2-mirage.json
# 17:25:26 [INFO] Reading in JSON from movistar-riders-vs-tyloo-m2-mirage.json
# 17:25:26 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:25:26 [INFO] Successfully parsed JSON output
# 17:25:26 [INFO] Successfully returned JSON output
# 17:25:27 [INFO] Returned dataframe output
# 17:25:27 [INFO] Go version>=1.14.0
# 17:25:27 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m3-vertigo.dem
# 17:25:27 [INFO] Setting demo id to movistar-riders-vs-tyloo-m3-vertigo
# 17:25:27 [INFO] Setting parse rate to 128
# 17:25:27 [INFO] Setting trade time to 5
# 17:25:27 [INFO] Setting buy style to hltv
# 17:25:27 [INFO] Rollup damages set to False
# 17:25:27 [INFO] Parse frames set to True
# 17:25:27 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:25:27 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-movistar-riders-vs-tyloo-bo3\movistar-riders-vs-tyloo-m3-vertigo.dem
# 17:25:43 [INFO] Wrote demo parse output to movistar-riders-vs-tyloo-m3-vertigo.json
# 17:25:43 [INFO] Reading in JSON from movistar-riders-vs-tyloo-m3-vertigo.json
# 17:25:44 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:25:44 [INFO] Successfully parsed JSON output
# 17:25:44 [INFO] Successfully returned JSON output
# 17:25:45 [INFO] Returned dataframe output
# Parsed demos for movistar-riders-vs-tyloo-bo3.
# 17:25:48 [INFO] Go version>=1.14.0
# 17:25:48 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m1-vertigo.dem
# 17:25:48 [INFO] Setting demo id to pain-vs-sharks-m1-vertigo
# 17:25:48 [INFO] Setting parse rate to 128
# 17:25:48 [INFO] Setting trade time to 5
# 17:25:48 [INFO] Setting buy style to hltv
# 17:25:48 [INFO] Rollup damages set to False
# 17:25:48 [INFO] Parse frames set to True
# 17:25:48 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:25:48 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m1-vertigo.dem
# 17:26:03 [INFO] Wrote demo parse output to pain-vs-sharks-m1-vertigo.json
# 17:26:03 [INFO] Reading in JSON from pain-vs-sharks-m1-vertigo.json
# 17:26:04 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:26:04 [INFO] Successfully parsed JSON output
# 17:26:04 [INFO] Successfully returned JSON output
# 17:26:04 [INFO] Returned dataframe output
# 17:26:05 [INFO] Go version>=1.14.0
# 17:26:05 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m2-ancient.dem
# 17:26:05 [INFO] Setting demo id to pain-vs-sharks-m2-ancient
# 17:26:05 [INFO] Setting parse rate to 128
# 17:26:05 [INFO] Setting trade time to 5
# 17:26:05 [INFO] Setting buy style to hltv
# 17:26:05 [INFO] Rollup damages set to False
# 17:26:05 [INFO] Parse frames set to True
# 17:26:05 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:26:05 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m2-ancient.dem
# 17:26:24 [INFO] Wrote demo parse output to pain-vs-sharks-m2-ancient.json
# 17:26:24 [INFO] Reading in JSON from pain-vs-sharks-m2-ancient.json
# 17:26:25 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:26:25 [INFO] Successfully parsed JSON output
# 17:26:25 [INFO] Successfully returned JSON output
# 17:26:26 [INFO] Returned dataframe output
# 17:26:26 [INFO] Go version>=1.14.0
# 17:26:26 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m3-nuke.dem
# 17:26:26 [INFO] Setting demo id to pain-vs-sharks-m3-nuke
# 17:26:26 [INFO] Setting parse rate to 128
# 17:26:26 [INFO] Setting trade time to 5
# 17:26:26 [INFO] Setting buy style to hltv
# 17:26:26 [INFO] Rollup damages set to False
# 17:26:26 [INFO] Parse frames set to True
# 17:26:26 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:26:26 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-pain-vs-sharks-bo3\pain-vs-sharks-m3-nuke.dem
# 17:26:36 [INFO] Wrote demo parse output to pain-vs-sharks-m3-nuke.json
# 17:26:36 [INFO] Reading in JSON from pain-vs-sharks-m3-nuke.json
# 17:26:36 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:26:36 [INFO] Successfully parsed JSON output
# 17:26:36 [INFO] Successfully returned JSON output
# 17:26:37 [INFO] Returned dataframe output
# 17:26:40 [INFO] Go version>=1.14.0
# Parsed demos for pain-vs-sharks-bo3.
# 17:26:40 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-spirit-vs-astralis-bo3\spirit-vs-astralis-m1-dust2.dem
# 17:26:40 [INFO] Setting demo id to spirit-vs-astralis-m1-dust2
# 17:26:40 [INFO] Setting parse rate to 128
# 17:26:40 [INFO] Setting trade time to 5
# 17:26:40 [INFO] Setting buy style to hltv
# 17:26:40 [INFO] Rollup damages set to False
# 17:26:40 [INFO] Parse frames set to True
# 17:26:40 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:26:40 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-spirit-vs-astralis-bo3\spirit-vs-astralis-m1-dust2.dem
# 17:26:52 [INFO] Wrote demo parse output to spirit-vs-astralis-m1-dust2.json
# 17:26:52 [INFO] Reading in JSON from spirit-vs-astralis-m1-dust2.json
# 17:26:53 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:26:53 [INFO] Successfully parsed JSON output
# 17:26:53 [INFO] Successfully returned JSON output
# 17:26:53 [INFO] Returned dataframe output
# 17:26:53 [INFO] Go version>=1.14.0
# 17:26:53 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-spirit-vs-astralis-bo3\spirit-vs-astralis-m2-inferno.dem
# 17:26:53 [INFO] Setting demo id to spirit-vs-astralis-m2-inferno
# 17:26:53 [INFO] Setting parse rate to 128
# 17:26:53 [INFO] Setting trade time to 5
# 17:26:53 [INFO] Setting buy style to hltv
# 17:26:53 [INFO] Rollup damages set to False
# 17:26:53 [INFO] Parse frames set to True
# 17:26:53 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:26:53 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-spirit-vs-astralis-bo3\spirit-vs-astralis-m2-inferno.dem
# 17:27:09 [INFO] Wrote demo parse output to spirit-vs-astralis-m2-inferno.json
# 17:27:09 [INFO] Reading in JSON from spirit-vs-astralis-m2-inferno.json
# 17:27:09 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:27:09 [INFO] Successfully parsed JSON output
# 17:27:09 [INFO] Successfully returned JSON output
# 17:27:10 [INFO] Returned dataframe output
# Parsed demos for spirit-vs-astralis-bo3.
# 17:27:12 [INFO] Go version>=1.14.0
# 17:27:12 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m1-inferno.dem
# 17:27:12 [INFO] Setting demo id to virtus-pro-vs-spirit-m1-inferno
# 17:27:12 [INFO] Setting parse rate to 128
# 17:27:12 [INFO] Setting trade time to 5
# 17:27:12 [INFO] Setting buy style to hltv
# 17:27:12 [INFO] Rollup damages set to False
# 17:27:12 [INFO] Parse frames set to True
# 17:27:12 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:27:12 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m1-inferno.dem
# 17:27:24 [INFO] Wrote demo parse output to virtus-pro-vs-spirit-m1-inferno.json
# 17:27:24 [INFO] Reading in JSON from virtus-pro-vs-spirit-m1-inferno.json
# 17:27:25 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:27:25 [INFO] Successfully parsed JSON output
# 17:27:25 [INFO] Successfully returned JSON output
# 17:27:26 [INFO] Returned dataframe output
# 17:27:26 [INFO] Go version>=1.14.0
# 17:27:26 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m2-ancient.dem
# 17:27:26 [INFO] Setting demo id to virtus-pro-vs-spirit-m2-ancient
# 17:27:26 [INFO] Setting parse rate to 128
# 17:27:26 [INFO] Setting trade time to 5
# 17:27:26 [INFO] Setting buy style to hltv
# 17:27:26 [INFO] Rollup damages set to False
# 17:27:26 [INFO] Parse frames set to True
# 17:27:26 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:27:26 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m2-ancient.dem
# 17:27:40 [INFO] Wrote demo parse output to virtus-pro-vs-spirit-m2-ancient.json
# 17:27:40 [INFO] Reading in JSON from virtus-pro-vs-spirit-m2-ancient.json
# 17:27:41 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:27:41 [INFO] Successfully parsed JSON output
# 17:27:41 [INFO] Successfully returned JSON output
# 17:27:41 [INFO] Returned dataframe output
# 17:27:42 [INFO] Go version>=1.14.0
# 17:27:42 [INFO] Initialized CSGODemoParser with demofile E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m3-overpass.dem
# 17:27:42 [INFO] Setting demo id to virtus-pro-vs-spirit-m3-overpass
# 17:27:42 [INFO] Setting parse rate to 128
# 17:27:42 [INFO] Setting trade time to 5
# 17:27:42 [INFO] Setting buy style to hltv
# 17:27:42 [INFO] Rollup damages set to False
# 17:27:42 [INFO] Parse frames set to True
# 17:27:42 [INFO] Running Golang parser from c:\program files\python38\lib\site-packages\csgo-1.0-py3.8.egg\csgo\parser\
# 17:27:42 [INFO] Looking for file at E:\Projects\HLTV\csgo_parser\demos\PGL Stockholm Major 2021 - Challengers\PGL-Major-Stockholm-2021-Challengers-Stage-virtus-pro-vs-spirit-bo3\virtus-pro-vs-spirit-m3-overpass.dem
# 17:28:00 [INFO] Wrote demo parse output to virtus-pro-vs-spirit-m3-overpass.json
# 17:28:00 [INFO] Reading in JSON from virtus-pro-vs-spirit-m3-overpass.json
# 17:28:01 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:28:01 [INFO] Successfully parsed JSON output
# 17:28:01 [INFO] Successfully returned JSON output
# 17:28:02 [INFO] Returned dataframe output
# Parsed demos for virtus-pro-vs-spirit-bo3.
